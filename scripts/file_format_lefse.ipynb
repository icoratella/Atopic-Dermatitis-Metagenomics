# %% [markdown]
# # Sheet 1: preparing data for the LEfSe Galaxy tool

# %% [markdown]
# ## Creating a file that corresponds to the **correct format for LEfSe**

# %% [markdown]
# **Input file format** (according to the LEfSe instructions): <br>
# The text tab-delimited input file consists of a list of numerical features, the class vector and optionally the subclass and subject vectors. The features can be read counts directly or abundance floating-point values more generally, and the first field is the name of the feature. Class, subclass and subject vectors have a name (the first field) and a list of non-numerical strings.
# Although both column and row feature organization is accepted, given the high-dimensional nature of metagenomic data, the listing of the features in rows is preferred.

# %% [markdown]
# ### **step 1:** *Loading the data*

# %%
import pandas as pd
Abundances = pd.read_excel(r"C:\Users\Ilaria Coratella\OneDrive - Universiteit Utrecht\Sapienza University - Ila\Internship Atopic Dermatitis\revised_data\AbbondanzerelativeSpecies.xlsx", sheet_name=None, index_col='Unnamed: 0')

# %%
print("Loaded sheets:", Abundances.keys())
df_abundance = Abundances['AbbondanzerelativeSpecies']
# Out:
# Loaded sheets: dict_keys(['AbbondanzerelativeSpecies'])

# %%
print(df_abundance.head(10).to_string())
# Out:
#           OTU                Sample  Abundance SampleType   Kingdom          Phylum                Class             Order                          Family              Genus                            Species
# 2826  taxa183  IFO/67-Mic-IFO-1_S67   0.000581         HS  Bacteria  Proteobacteria  Gammaproteobacteria   Pseudomonadales                   Moraxellaceae      Acinetobacter         Acinetobacter haemolyticus
# 2469  taxa172  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria  Proteobacteria  Gammaproteobacteria   Pseudomonadales                   Moraxellaceae      Acinetobacter              Acinetobacter lwoffii
# 4007  taxa241  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria  Proteobacteria  Gammaproteobacteria   Pseudomonadales                   Moraxellaceae      Acinetobacter           Acinetobacter sp. Hg4-05
# 2307  taxa169  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria  Proteobacteria  Gammaproteobacteria   Pseudomonadales                   Moraxellaceae      Acinetobacter           Acinetobacter sp. JUN-14
# 6859  taxa474  IFO/67-Mic-IFO-1_S67   0.000016         HS  Bacteria  Actinobacteria       Actinobacteria   Actinomycetales            Propionibacteriaceae  Propionibacterium        actinobacterium PI GH2.1.C2
# 4550  taxa290  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria  Proteobacteria  Gammaproteobacteria   Pseudomonadales                   Moraxellaceae      Enhydrobacter  Actinomycetales bacterium XJSS-08
# 4248  taxa256  IFO/67-Mic-IFO-1_S67   0.000041         HS  Bacteria  Actinobacteria       Actinobacteria   Actinomycetales                  Micrococcaceae       Arthrobacter           Arthrobacter davidanieli
# 768   taxa121  IFO/67-Mic-IFO-1_S67   0.000311         HS  Bacteria  Actinobacteria       Actinobacteria   Actinomycetales                  Micrococcaceae       Arthrobacter             Arthrobacter sp. mb182
# 6132   taxa40  IFO/67-Mic-IFO-1_S67   0.007247         HS  Bacteria  Proteobacteria   Betaproteobacteria   Burkholderiales  Burkholderiales incertae sedis      Aquabacterium             Bacillus sp. CE2(2012)
# 4165  taxa252  IFO/67-Mic-IFO-1_S67   0.000147         HS  Bacteria  Proteobacteria  Alphaproteobacteria  Sphingomonadales               Sphingomonadaceae       Sphingomonas                   bacterium 072822

# %% [markdown]
# ### **Step 2:** *Creating a new dataframe*
# the columns will be the samples, while I'm adding, for now, just the first row SampleType

# %%
unique_samples = df_abundance['Sample'].unique()

# For each unique sample value, this line extracts the associated value of SampleType and save it in the sample_types dictionaries
sample_types = {sample: df_abundance.loc[df_abundance['Sample'] == sample, 'SampleType'].iloc[0] for sample in unique_samples}

#Creates the new dataframe
df_new_format = pd.DataFrame(index=['SampleType'], columns=unique_samples)

# Assigns to the row with the index 'SampleType' the values mapped from the column names (which are the unique sample values)
df_new_format.loc['SampleType', :] = df_new_format.columns.map(sample_types)
print(df_new_format.head(10).to_string())
# Out:
#            IFO/67-Mic-IFO-1_S67 IFO/68-Mic-IFO-2_S68 IFO/69-Mic-IFO-3_S69 IFO/B1_S1 IFO/B2_S2 IFO/B5_S5 IFO/B6_S6 IFO/B9_S9 IFO/B10_S10 IFO/B13_S4 IFO/B14_S5 IFO/B16_S7 IFO/B17_S8 IFO/B18_S9 IFO/B19_S10 IFO/B21_S12 IFO/B22_S25 IFO/B25_S28 IFO/B26_S29 IFO/B29_S32 IFO/B30_S33 IFO/B33_S36 IFO/B34_S37 IFO/B37_S40 IFO/B38_S41 IFO/B41_S44 IFO/B42_S45 IFO/B45_S48 IFO/B48_S3 IFO/B49_S4 IFO/B51_S6 IFO/B53_S8 IFO/B54_S9 IFO/B55_S10 IFO/B57_S1 IFO/B58_S2 IFO/B61_S5 IFO/B62_S6 IFO/v3_S1 IFO/v5_S3 IFO/v6_S4 IFO/v10_S8 IFO/v13_S11 IFO/v14_S12
# SampleType                   HS                   HS                   HS        LE        NL        LE        NL        LE          NL         LE         NL         HS         LE         NL          HS          LE          NL          LE          NL          NL          LE          NL          LE          LE          NL          NL          LE          LE         HS         LE         HS         NL         LE          HS         LE         NL         NL         LE        HS        HS        HS         HS          HS          HS

# %% [markdown]
# ### **Step 3:** *Adding the previous taxonomic details in each of the taxonomic columns*

# %%
# Isolating the taxonomic levels
taxonomic_columns = ['Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species']

# To be sure no nan are in the columns
df_abundance[taxonomic_columns] = df_abundance[taxonomic_columns].fillna(method='ffill', axis=1)

# A loop for adding the names in the previous column in the present one
for i in range(1, len(taxonomic_columns)):
    df_abundance[taxonomic_columns[i]] = df_abundance[taxonomic_columns[i-1]] + '|' + df_abundance[taxonomic_columns[i]]

print(df_abundance.head())
# Out:
#           OTU                Sample  Abundance SampleType   Kingdom  \
# 2826  taxa183  IFO/67-Mic-IFO-1_S67   0.000581         HS  Bacteria
# 2469  taxa172  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria
# 4007  taxa241  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria
# 2307  taxa169  IFO/67-Mic-IFO-1_S67   0.000000         HS  Bacteria
# 6859  taxa474  IFO/67-Mic-IFO-1_S67   0.000016         HS  Bacteria
#
#                        Phylum                                        Class  \
# 2826  Bacteria|Proteobacteria  Bacteria|Proteobacteria|Gammaproteobacteria
# 2469  Bacteria|Proteobacteria  Bacteria|Proteobacteria|Gammaproteobacteria
# 4007  Bacteria|Proteobacteria  Bacteria|Proteobacteria|Gammaproteobacteria
# 2307  Bacteria|Proteobacteria  Bacteria|Proteobacteria|Gammaproteobacteria
# 6859  Bacteria|Actinobacteria       Bacteria|Actinobacteria|Actinobacteria
#
#                                                   Order  \
# 2826  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2469  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 4007  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2307  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 6859  Bacteria|Actinobacteria|Actinobacteria|Actinom...
#
#                                                  Family  \
# 2826  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2469  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 4007  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2307  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 6859  Bacteria|Actinobacteria|Actinobacteria|Actinom...
#
#                                                   Genus  \
# 2826  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2469  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 4007  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2307  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 6859  Bacteria|Actinobacteria|Actinobacteria|Actinom...
#
#                                                 Species
# 2826  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2469  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 4007  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 2307  Bacteria|Proteobacteria|Gammaproteobacteria|Ps...
# 6859  Bacteria|Actinobacteria|Actinobacteria|Actinom...
# C:\Users\Ilaria Coratella\AppData\Local\Temp\ipykernel_28536\3827212077.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_abundance[taxonomic_columns] = df_abundance[taxonomic_columns].fillna(method='ffill', axis=1)

# %% [markdown]
# ### **Step 4:** *computing the relative abundance for each taxonomic type in each taxonomic level, and adding each new row to the newly created dataset*

# %%
for level in taxonomic_columns:

    # Create new temporary dataframe with aggregated abundance per Sample and level
    grouped_abundance = df_abundance.groupby(['Sample', level]).agg({'Abundance': 'sum'}).reset_index()
    
    # Reshape the new dataframe
    pivot_abundance = grouped_abundance.pivot(index=level, columns='Sample', values='Abundance')

    # Concatenate the newly reshaped df to the previous level df
    df_new_format = pd.concat([df_new_format, pivot_abundance], axis=0)

display(df_new_format.head(100))
# Out:
#                                                    IFO/67-Mic-IFO-1_S67  \
# SampleType                                                           HS
# Bacteria                                                            1.0
# Bacteria|Actinobacteria                                        0.181763
# Bacteria|Bacteroidetes                                         0.001974
# Bacteria|Firmicutes                                            0.537714
# ...                                                                 ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...             0.000336
# Bacteria|Proteobacteria|unclassified Proteobact...             0.012636
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000246
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.01049
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000139
#
#                                                    IFO/68-Mic-IFO-2_S68  \
# SampleType                                                           HS
# Bacteria                                                            1.0
# Bacteria|Actinobacteria                                        0.434501
# Bacteria|Bacteroidetes                                         0.000234
# Bacteria|Firmicutes                                            0.448171
# ...                                                                 ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...             0.002202
# Bacteria|Proteobacteria|unclassified Proteobact...             0.013822
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000632
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.049092
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000591
#
#                                                    IFO/69-Mic-IFO-3_S69  \
# SampleType                                                           HS
# Bacteria                                                            1.0
# Bacteria|Actinobacteria                                        0.411035
# Bacteria|Bacteroidetes                                         0.000217
# Bacteria|Firmicutes                                            0.481841
# ...                                                                 ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...             0.000315
# Bacteria|Proteobacteria|unclassified Proteobact...             0.001132
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000972
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.056616
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...             0.000692
#
#                                                    IFO/B1_S1 IFO/B2_S2  \
# SampleType                                                LE        NL
# Bacteria                                                 1.0       1.0
# Bacteria|Actinobacteria                             0.158589  0.092922
# Bacteria|Bacteroidetes                              0.009103  0.000246
# Bacteria|Firmicutes                                 0.109816   0.06317
# ...                                                      ...       ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.00366  0.006314
# Bacteria|Proteobacteria|unclassified Proteobact...  0.001322  0.002433
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.001261       0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.003167  0.009394
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.000031  0.000123
#
#                                                    IFO/B5_S5 IFO/B6_S6  \
# SampleType                                                LE        NL
# Bacteria                                                 1.0       1.0
# Bacteria|Actinobacteria                             0.337041  0.155943
# Bacteria|Bacteroidetes                              0.000405  0.001054
# Bacteria|Firmicutes                                 0.156257  0.100456
# ...                                                      ...       ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...  0.003683  0.002817
# Bacteria|Proteobacteria|unclassified Proteobact...   0.01602   0.00205
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.00151  0.016229
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.074832   0.03947
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.001363  0.000575
#
#                                                    IFO/B9_S9 IFO/B10_S10  \
# SampleType                                                LE          NL
# Bacteria                                                 1.0         1.0
# Bacteria|Actinobacteria                             0.224554    0.242788
# Bacteria|Bacteroidetes                              0.000489    0.006497
# Bacteria|Firmicutes                                 0.173042    0.096835
# ...                                                      ...         ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...  0.004659     0.00171
# Bacteria|Proteobacteria|unclassified Proteobact...  0.001825     0.00628
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...       0.0         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.004008    0.000373
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.000033    0.000031
#
#                                                    IFO/B13_S4  ... IFO/B57_S1  \
# SampleType                                                 LE  ...         LE
# Bacteria                                                  1.0  ...        1.0
# Bacteria|Actinobacteria                              0.324302  ...   0.145185
# Bacteria|Bacteroidetes                               0.000043  ...   0.000898
# Bacteria|Firmicutes                                  0.325329  ...   0.169199
# ...                                                       ...  ...        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.001348  ...   0.004166
# Bacteria|Proteobacteria|unclassified Proteobact...   0.000321  ...   0.002042
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0  ...        0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.006164  ...   0.038063
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.001477  ...   0.001021
#
#                                                    IFO/B58_S2 IFO/B61_S5  \
# SampleType                                                 NL         NL
# Bacteria                                                  1.0        1.0
# Bacteria|Actinobacteria                              0.086599   0.098156
# Bacteria|Bacteroidetes                               0.000283   0.000994
# Bacteria|Firmicutes                                  0.049671   0.018402
# ...                                                       ...        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...    0.00572    0.00368
# Bacteria|Proteobacteria|unclassified Proteobact...   0.002322   0.003975
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.00017   0.000037
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.002096   0.002098
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0        0.0
#
#                                                    IFO/B62_S6 IFO/v3_S1  \
# SampleType                                                 LE        HS
# Bacteria                                                  1.0       1.0
# Bacteria|Actinobacteria                              0.093822  0.250102
# Bacteria|Bacteroidetes                                0.00139  0.000192
# Bacteria|Firmicutes                                  0.016104  0.082952
# ...                                                       ...       ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.006207  0.013359
# Bacteria|Proteobacteria|unclassified Proteobact...   0.002157  0.003783
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0       0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.007309  0.006368
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.00012  0.000239
#
#                                                    IFO/v5_S3 IFO/v6_S4  \
# SampleType                                                HS        HS
# Bacteria                                                 1.0       1.0
# Bacteria|Actinobacteria                             0.362797  0.593479
# Bacteria|Bacteroidetes                              0.000203       0.0
# Bacteria|Firmicutes                                 0.532882  0.227897
# ...                                                      ...       ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...  0.002962  0.002638
# Bacteria|Proteobacteria|unclassified Proteobact...  0.000496  0.000484
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...       0.0  0.000022
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...  0.003483  0.004463
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.00014  0.000066
#
#                                                    IFO/v10_S8 IFO/v13_S11  \
# SampleType                                                 HS          HS
# Bacteria                                                  1.0         1.0
# Bacteria|Actinobacteria                              0.421711    0.767937
# Bacteria|Bacteroidetes                               0.003578    0.000016
# Bacteria|Firmicutes                                  0.023379    0.130137
# ...                                                       ...         ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.011525     0.00087
# Bacteria|Proteobacteria|unclassified Proteobact...    0.00433    0.001116
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.00029    0.001493
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0    0.000328
#
#                                                    IFO/v14_S12
# SampleType                                                  HS
# Bacteria                                                   1.0
# Bacteria|Actinobacteria                                0.29157
# Bacteria|Bacteroidetes                                0.000019
# Bacteria|Firmicutes                                   0.005821
# ...                                                        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...    0.012667
# Bacteria|Proteobacteria|unclassified Proteobact...    0.004347
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...         0.0
#
# [100 rows x 44 columns]

# %%
# adding the 'Sample' variable to the rows
new_row = pd.DataFrame([df_new_format.columns], columns=df_new_format.columns)
df_new_format = pd.concat([new_row, df_new_format])

# %%
df_new_format.rename(index={0: 'Sample'}, inplace=True)

# %%
display(df_new_format.head(100))
# Out:
#                                                     IFO/67-Mic-IFO-1_S67  \
# Sample                                              IFO/67-Mic-IFO-1_S67
# SampleType                                                            HS
# Bacteria                                                             1.0
# Bacteria|Actinobacteria                                         0.181763
# Bacteria|Bacteroidetes                                          0.001974
# ...                                                                  ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...              0.001302
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...              0.000336
# Bacteria|Proteobacteria|unclassified Proteobact...              0.012636
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.000246
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...               0.01049
#
#                                                     IFO/68-Mic-IFO-2_S68  \
# Sample                                              IFO/68-Mic-IFO-2_S68
# SampleType                                                            HS
# Bacteria                                                             1.0
# Bacteria|Actinobacteria                                         0.434501
# Bacteria|Bacteroidetes                                          0.000234
# ...                                                                  ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...              0.000877
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...              0.002202
# Bacteria|Proteobacteria|unclassified Proteobact...              0.013822
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.000632
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.049092
#
#                                                     IFO/69-Mic-IFO-3_S69  \
# Sample                                              IFO/69-Mic-IFO-3_S69
# SampleType                                                            HS
# Bacteria                                                             1.0
# Bacteria|Actinobacteria                                         0.411035
# Bacteria|Bacteroidetes                                          0.000217
# ...                                                                  ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...                   0.0
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...              0.000315
# Bacteria|Proteobacteria|unclassified Proteobact...              0.001132
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.000972
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...              0.056616
#
#                                                     IFO/B1_S1  IFO/B2_S2  \
# Sample                                              IFO/B1_S1  IFO/B2_S2
# SampleType                                                 LE         NL
# Bacteria                                                  1.0        1.0
# Bacteria|Actinobacteria                              0.158589   0.092922
# Bacteria|Bacteroidetes                               0.009103   0.000246
# ...                                                       ...        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...        0.0   0.004589
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...    0.00366   0.006314
# Bacteria|Proteobacteria|unclassified Proteobact...   0.001322   0.002433
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.001261        0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.003167   0.009394
#
#                                                     IFO/B5_S5  IFO/B6_S6  \
# Sample                                              IFO/B5_S5  IFO/B6_S6
# SampleType                                                 LE         NL
# Bacteria                                                  1.0        1.0
# Bacteria|Actinobacteria                              0.337041   0.155943
# Bacteria|Bacteroidetes                               0.000405   0.001054
# ...                                                       ...        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...    0.01068   0.000402
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.003683   0.002817
# Bacteria|Proteobacteria|unclassified Proteobact...    0.01602    0.00205
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.00151   0.016229
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.074832    0.03947
#
#                                                     IFO/B9_S9  IFO/B10_S10  \
# Sample                                              IFO/B9_S9  IFO/B10_S10
# SampleType                                                 LE           NL
# Bacteria                                                  1.0          1.0
# Bacteria|Actinobacteria                              0.224554     0.242788
# Bacteria|Bacteroidetes                               0.000489     0.006497
# ...                                                       ...          ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...   0.001759     0.003202
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.004659      0.00171
# Bacteria|Proteobacteria|unclassified Proteobact...   0.001825      0.00628
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0          0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.004008     0.000373
#
#                                                     IFO/B13_S4  ...  \
# Sample                                              IFO/B13_S4  ...
# SampleType                                                  LE  ...
# Bacteria                                                   1.0  ...
# Bacteria|Actinobacteria                               0.324302  ...
# Bacteria|Bacteroidetes                                0.000043  ...
# ...                                                        ...  ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...         0.0  ...
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...    0.001348  ...
# Bacteria|Proteobacteria|unclassified Proteobact...    0.000321  ...
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...         0.0  ...
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.006164  ...
#
#                                                     IFO/B57_S1  IFO/B58_S2  \
# Sample                                              IFO/B57_S1  IFO/B58_S2
# SampleType                                                  LE          NL
# Bacteria                                                   1.0         1.0
# Bacteria|Actinobacteria                               0.145185    0.086599
# Bacteria|Bacteroidetes                                0.000898    0.000283
# ...                                                        ...         ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...     0.00098    0.001643
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...    0.004166     0.00572
# Bacteria|Proteobacteria|unclassified Proteobact...    0.002042    0.002322
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...         0.0     0.00017
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.038063    0.002096
#
#                                                     IFO/B61_S5  IFO/B62_S6  \
# Sample                                              IFO/B61_S5  IFO/B62_S6
# SampleType                                                  NL          LE
# Bacteria                                                   1.0         1.0
# Bacteria|Actinobacteria                               0.098156    0.093822
# Bacteria|Bacteroidetes                                0.000994     0.00139
# ...                                                        ...         ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...    0.001031         0.0
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...     0.00368    0.006207
# Bacteria|Proteobacteria|unclassified Proteobact...    0.003975    0.002157
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.000037         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...    0.002098    0.007309
#
#                                                     IFO/v3_S1  IFO/v5_S3  \
# Sample                                              IFO/v3_S1  IFO/v5_S3
# SampleType                                                 HS         HS
# Bacteria                                                  1.0        1.0
# Bacteria|Actinobacteria                              0.250102   0.362797
# Bacteria|Bacteroidetes                               0.000192   0.000203
# ...                                                       ...        ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...    0.00249   0.000318
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.013359   0.002962
# Bacteria|Proteobacteria|unclassified Proteobact...   0.003783   0.000496
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...        0.0        0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.006368   0.003483
#
#                                                     IFO/v6_S4  IFO/v10_S8  \
# Sample                                              IFO/v6_S4  IFO/v10_S8
# SampleType                                                 HS          HS
# Bacteria                                                  1.0         1.0
# Bacteria|Actinobacteria                              0.593479    0.421711
# Bacteria|Bacteroidetes                                    0.0    0.003578
# ...                                                       ...         ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...        0.0     0.00037
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...   0.002638    0.011525
# Bacteria|Proteobacteria|unclassified Proteobact...   0.000484     0.00433
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.000022         0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...   0.004463     0.00029
#
#                                                     IFO/v13_S11  IFO/v14_S12
# Sample                                              IFO/v13_S11  IFO/v14_S12
# SampleType                                                   HS           HS
# Bacteria                                                    1.0          1.0
# Bacteria|Actinobacteria                                0.767937      0.29157
# Bacteria|Bacteroidetes                                 0.000016     0.000019
# ...                                                         ...          ...
# Bacteria|Proteobacteria|Gammaproteobacteria|Xan...     0.000279     0.000019
# Bacteria|Proteobacteria|Gammaproteobacteria|unc...      0.00087     0.012667
# Bacteria|Proteobacteria|unclassified Proteobact...     0.001116     0.004347
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...          0.0          0.0
# Bacteria|Actinobacteria|Actinobacteria|Actinomy...     0.001493          0.0
#
# [100 rows x 44 columns]
